# %% [markdown]
# ## **Travelling Salesperson Problem**

# %%
import pandas as pd
from icecream import ic
import numpy as np
import random
import math
from geopy.distance import geodesic

# %% [markdown]
# ## Approach 1: **Best greedy solution**
# This first trivial approach is based on a greedy algorithm where the local optimum, at each step, is represented by the closest city among the ones that have not been visited yet. The greedy process is repeated as many times as the number of cities, and each time the path starts from a different city.<br>
# The one greedy solution that is chosen as the final one is the one whose overall distance is shorter.<br>

# %%
class City:
    def __init__(self, name, x, y):
        self.name = name
        self.x = x
        self.y = y

source = pd.read_csv("cities/italy.csv", names=["city", "x", "y"])
cities = list()

# initialization of the cities list with City objects
for index, row in source.iterrows():
    cities.append(City(row["city"], row["x"], row["y"]))

NUM_CITIES = len(cities)

# %% [markdown]
# The distance between the cities can be measured either using euclidean distance or using `geodesic()` function (based on latitude and longitude). The code is parametrized so that the distance measurement method can be changed by setting the `DISTANCE` constant to `"euclidean"` or `"geodesic"`.<br>
# **NOTE**: changing the type of distance does not impact on the algorithm strategy or on final solution.

# %%
DISTANCE = "geodesic"
# the function calculates the euclidean distance between two cities
def euclidean_distance(city_1, city_2):
    return math.sqrt(math.pow((city_1.x - city_2.x), 2) + math.pow((city_1.y - city_2.y), 2))

# matrix containing the precalculated geodesic distances
DIST_MATRIX = np.zeros((len(cities), len(cities)))
# the function calculates the geodesic distance between two cities
def geodesic_distance(city_1, city_2):
    return DIST_MATRIX[cities.index(city_1), cities.index(city_2)]

# initialization of the geodesic distances matrix
if DISTANCE == "geodesic":
    for i in range(len(cities)):
        for j in range(len(cities)):
            point_1 = (cities[i].x, cities[i].y)
            point_2 = (cities[j].x, cities[j].y)
            DIST_MATRIX[i, j] = geodesic(point_1, point_2).kilometers

# the function returns the distance among two cities according to the selected distance method
def get_distance(city_1, city_2):
    if DISTANCE == "euclidean":
        return euclidean_distance(city_1, city_2)
    else:
        return geodesic_distance(city_1, city_2)

# %%
# the function checks whether a candidate city is already in the solution (i.e. it has already been visited)
def not_in_solution(city, solution):
    flag = True
    for sol_city in (solution[0]):
        if sol_city.name == city.name:
            flag = False
            break

    return flag

# the function returns the available city that is closer to the last one visited
def get_closest_city(solution):
    closer_dist = float("inf")
    closer_city = None
    for city in cities:
        dist = get_distance(solution[0][-1], city)
        if dist != 0 and dist < closer_dist and not_in_solution(city, solution):
            closer_city = city
            closer_dist = dist
    
    solution[0].append(closer_city)
    new_solution = (solution[0], solution[1] + closer_dist)
    return new_solution

# the function prints the final result
def print_solution(solution):
    print("PATH:")
    for i in range(0, NUM_CITIES - 1):
        print("(" + solution[i].name + " -> " + solution[i + 1].name + ") DISTANCE: " + str(get_distance(solution[i], solution[i + 1])))
    print("(" + solution[-1].name + " -> " + solution[0].name + ") DISTANCE: " + str(get_distance(solution[-1], solution[0])))
    print("TOTAL DISTANCE: " + str(recalculate_distance(solution)))

# the function recalculates the overall path distance after the city swap performed in the 2-opt
def recalculate_distance(path):
    dist = 0.0
    for i in range(0, NUM_CITIES - 1):
        dist += get_distance(path[i], path[i + 1])
    dist += get_distance(path[-1], path[0])
    return dist

# %%
best_result = float("inf")

# the greedy algorithm is repeated each time with a different starting city
for i in range(0, NUM_CITIES):
    starting_city = cities[i]
    # initialization of the solution
    candidate_solution = ([starting_city], 0.0)

    solution = candidate_solution
    # at each iteration a new city is added to the path; the city is chosen so that it is the closest
    # one to the last visited city
    for _ in range(NUM_CITIES - 1):
        solution = get_closest_city(solution)

    # the distance needed to come back to the starting city is added to the total path distance
    solution = (solution[0], solution[1] + get_distance(starting_city, solution[0][-1]))
    # the 2-opt technique is performed on the greedy solution in order to try to improve it
    # solution = two_opt(solution)
    # if the current greedy solution is the best one then it's set as the final one
    if solution[1] < best_result:
        best_result = solution[1]
        best_greedy = solution

print_solution(best_greedy[0])
# Out:
# PATH:
# (Ancona -> Rimini) DISTANCE: 90.5967461797061
# (Rimini -> Forlì) DISTANCE: 46.723760122246745
# (Forlì -> Ravenna) DISTANCE: 26.45904737732812
# (Ravenna -> Ferrara) DISTANCE: 66.67171194357726
# (Ferrara -> Bologna) DISTANCE: 43.42728615199659
# (Bologna -> Modena) DISTANCE: 37.29202792818561
# (Modena -> Reggio nell'Emilia) DISTANCE: 23.939721051289947
# (Reggio nell'Emilia -> Parma) DISTANCE: 26.942823860477837
# (Parma -> Piacenza) DISTANCE: 57.65426248112829
# (Piacenza -> Milan) DISTANCE: 60.64923118840254
# (Milan -> Monza) DISTANCE: 14.50856854090449
# (Monza -> Bergamo) DISTANCE: 33.91792128864521
# (Bergamo -> Brescia) DISTANCE: 46.01771032749969
# (Brescia -> Verona) DISTANCE: 61.41588754627765
# (Verona -> Vicenza) DISTANCE: 44.69517255475827
# (Vicenza -> Padua) DISTANCE: 30.129893989361843
# (Padua -> Venice) DISTANCE: 36.07208970412391
# (Venice -> Trieste) DISTANCE: 115.09339706818346
# (Trieste -> Bolzano) DISTANCE: 209.6848929934776
# (Bolzano -> Trento) DISTANCE: 49.93679674999438
# (Trento -> Novara) DISTANCE: 206.68711345185295
# (Novara -> Turin) DISTANCE: 84.45894281264431
# (Turin -> Genoa) DISTANCE: 123.19477068521964
# (Genoa -> Leghorn) DISTANCE: 146.36826834006118
# (Leghorn -> Prato) DISTANCE: 74.0242139473328
# (Prato -> Florence) DISTANCE: 17.17330189828679
# (Florence -> Perugia) DISTANCE: 119.19198932605904
# (Perugia -> Terni) DISTANCE: 63.64271193762265
# (Terni -> Rome) DISTANCE: 76.5411082252729
# (Rome -> Latina) DISTANCE: 56.837851102893964
# (Latina -> Giugliano in Campania) DISTANCE: 124.44567231892404
# (Giugliano in Campania -> Naples) DISTANCE: 11.1526869070739
# (Naples -> Salerno) DISTANCE: 46.24532696291669
# (Salerno -> Foggia) DISTANCE: 109.51661720605695
# (Foggia -> Andria) DISTANCE: 67.42173103569236
# (Andria -> Bari) DISTANCE: 50.17877214765558
# (Bari -> Taranto) DISTANCE: 77.62816934136235
# (Taranto -> Messina) DISTANCE: 293.01721721226914
# (Messina -> Reggio di Calabria) DISTANCE: 12.477352214328397
# (Reggio di Calabria -> Catania) DISTANCE: 84.28339538220968
# (Catania -> Syracuse) DISTANCE: 51.227395340192665
# (Syracuse -> Palermo) DISTANCE: 206.4685647180968
# (Palermo -> Cagliari) DISTANCE: 390.2811320384364
# (Cagliari -> Sassari) DISTANCE: 173.89062184125248
# (Sassari -> Pescara) DISTANCE: 508.60942288264704
# (Pescara -> Ancona) DISTANCE: 139.23847120123253
# TOTAL DISTANCE: 4436.03176952516

# %% [markdown]
# ## Approach 2: **Best greedy solution with 2-opt**
# In this second approach we try to improve the best greedy solution by adding an iterative 2-opt mutation to the solution for a fixed number of times.<br>
# The implemented fitness functions are two:<br>
# - `fitness()`: based on the total distance of the path
# - `fitness_var()`: based on the variance of the length of the segments connecting the cities along the path. This is made in order to make the overall path more "balanced" with respect to the distances and also in order to try to fix the greedy scenario where the local optimality (closest city) does not necessarily correspond to the global optimality (shortest path).

# %%
# fitness function baed on distance
def fitness(solution):
    return -recalculate_distance(solution)

# fitness function based on variance, calculated as (x - u)^2 for each city x, where u is the 
# value of the average length of the segments connecting the cities in the current solution path
def fitness_var(solution):
    sum = 0.0
    for i in range(0, NUM_CITIES - 1):
        sum += get_distance(solution[i], solution[i + 1])
    sum += get_distance(solution[-1], solution[0])
    avg = sum / NUM_CITIES

    var = 0.0
    for i in range(0, NUM_CITIES - 1):
        var += math.pow((get_distance(solution[i], solution[i + 1]) - avg), 2)
    var += math.pow((get_distance(solution[-1], solution[0]) - avg), 2)

    return (-sum, - var)


# the 2-opt function performs the swap of two random cities
def two_opt(solution):
    # selection of the two cities to be swapped
    edge_1 = random.randint(0, (NUM_CITIES - 1))
    edge_2 = random.randint(0, (NUM_CITIES - 1))
    while edge_2 == edge_1:
        edge_2 = random.randint(0, (NUM_CITIES - 1))
    
    # the cities are swapped and the new distance is calculated
    new_path = solution.copy()
    temp = new_path[edge_1]
    new_path[edge_1] = new_path[edge_2]
    new_path[edge_2] = temp
    new_solution = new_path
            
    return new_solution


# iterative process
# the starting solution is the best greedy solution
solution = best_greedy[0].copy()
for _ in range(1000):
    new_solution = two_opt(solution)

    if fitness_var(new_solution) > fitness_var(solution):
        solution = new_solution

print_solution(solution)
# Out:
# PATH:
# (Ancona -> Rimini) DISTANCE: 90.5967461797061
# (Rimini -> Forlì) DISTANCE: 46.723760122246745
# (Forlì -> Ravenna) DISTANCE: 26.45904737732812
# (Ravenna -> Ferrara) DISTANCE: 66.67171194357726
# (Ferrara -> Bologna) DISTANCE: 43.42728615199659
# (Bologna -> Modena) DISTANCE: 37.29202792818561
# (Modena -> Reggio nell'Emilia) DISTANCE: 23.939721051289947
# (Reggio nell'Emilia -> Parma) DISTANCE: 26.942823860477837
# (Parma -> Piacenza) DISTANCE: 57.65426248112829
# (Piacenza -> Milan) DISTANCE: 60.64923118840254
# (Milan -> Monza) DISTANCE: 14.50856854090449
# (Monza -> Bergamo) DISTANCE: 33.91792128864521
# (Bergamo -> Brescia) DISTANCE: 46.01771032749969
# (Brescia -> Verona) DISTANCE: 61.41588754627765
# (Verona -> Vicenza) DISTANCE: 44.69517255475827
# (Vicenza -> Padua) DISTANCE: 30.129893989361843
# (Padua -> Venice) DISTANCE: 36.07208970412391
# (Venice -> Trieste) DISTANCE: 115.09339706818346
# (Trieste -> Bolzano) DISTANCE: 209.6848929934776
# (Bolzano -> Trento) DISTANCE: 49.93679674999438
# (Trento -> Novara) DISTANCE: 206.68711345185295
# (Novara -> Turin) DISTANCE: 84.45894281264431
# (Turin -> Genoa) DISTANCE: 123.19477068521964
# (Genoa -> Leghorn) DISTANCE: 146.36826834006118
# (Leghorn -> Prato) DISTANCE: 74.0242139473328
# (Prato -> Florence) DISTANCE: 17.17330189828679
# (Florence -> Perugia) DISTANCE: 119.19198932605904
# (Perugia -> Terni) DISTANCE: 63.64271193762265
# (Terni -> Rome) DISTANCE: 76.5411082252729
# (Rome -> Latina) DISTANCE: 56.837851102893964
# (Latina -> Giugliano in Campania) DISTANCE: 124.44567231892404
# (Giugliano in Campania -> Naples) DISTANCE: 11.1526869070739
# (Naples -> Salerno) DISTANCE: 46.24532696291669
# (Salerno -> Foggia) DISTANCE: 109.51661720605695
# (Foggia -> Andria) DISTANCE: 67.42173103569236
# (Andria -> Bari) DISTANCE: 50.17877214765558
# (Bari -> Taranto) DISTANCE: 77.62816934136235
# (Taranto -> Messina) DISTANCE: 293.01721721226914
# (Messina -> Reggio di Calabria) DISTANCE: 12.477352214328397
# (Reggio di Calabria -> Syracuse) DISTANCE: 119.72689054756697
# (Syracuse -> Catania) DISTANCE: 51.227395340192665
# (Catania -> Palermo) DISTANCE: 166.3570679647983
# (Palermo -> Cagliari) DISTANCE: 390.2811320384364
# (Cagliari -> Sassari) DISTANCE: 173.89062184125248
# (Sassari -> Pescara) DISTANCE: 508.60942288264704
# (Pescara -> Ancona) DISTANCE: 139.23847120123253
# TOTAL DISTANCE: 4431.363767937219

# %% [markdown]
# ## Approach 3: **Hill climbing with 2-opt and simulated annealing**
# This third approach starts from a random solution and tries to iprove it with a 2-opt tweak. The algorithm also implements simulated annealing using a "temeperature" level that represents the number of times the tweak is applied to the current solution (i.e. if the temperature is low the solution is slightly changed, while if the temperature is high the solution is highly changed as well).

# %%
temperature = 1
BUFFER_SIZE = 4
buffer = list()

# the function performs as many random city swaps as the value of the temperature
def two_opt_sa(solution):
    for _ in range(int(temperature)):
        # selection of the two cities to be swapped
        edge_1 = random.randint(0, (NUM_CITIES - 1))
        edge_2 = random.randint(0, (NUM_CITIES - 1))
        while edge_2 == edge_1:
            edge_2 = random.randint(0, (NUM_CITIES - 1))
        
        # the cities are swapped and the new distance is calculated
        new_path = solution.copy()
        temp = new_path[edge_1]
        new_path[edge_1] = new_path[edge_2]
        new_path[edge_2] = temp
        new_solution = new_path

        solution = new_solution
            
    return solution


# we start from a random solution
random_path = best_greedy[0].copy()
random.shuffle(random_path)
solution = random_path
print_solution(solution)

# iterative process
for _ in range(1000):
    new_solution = two_opt_sa(solution)

    buffer.append(fitness(new_solution) > fitness(solution))
    buffer = buffer[-BUFFER_SIZE:]

    # variation of the temperature
    if sum(buffer) > BUFFER_SIZE / 2 and temperature > 1:
        temperature -= 1
    elif sum(buffer) < BUFFER_SIZE / 2:
        temperature += 1

    if fitness(new_solution) > fitness(solution):
        solution = new_solution
    
print_solution(solution)
# Out:
# PATH:
# (Genoa -> Modena) DISTANCE: 160.21649089511217
# (Modena -> Sassari) DISTANCE: 476.41905206831524
# (Sassari -> Forlì) DISTANCE: 481.2645999521971
# (Forlì -> Bologna) DISTANCE: 63.195906335518075
# (Bologna -> Brescia) DISTANCE: 146.3109576361904
# (Brescia -> Palermo) DISTANCE: 865.2955345615519
# (Palermo -> Salerno) DISTANCE: 309.0689134010174
# (Salerno -> Giugliano in Campania) DISTANCE: 56.26767299492243
# (Giugliano in Campania -> Reggio di Calabria) DISTANCE: 337.30941864101976
# (Reggio di Calabria -> Florence) DISTANCE: 730.7426536094483
# (Florence -> Catania) DISTANCE: 769.0849052550734
# (Catania -> Ferrara) DISTANCE: 865.3842909130826
# (Ferrara -> Venice) DISTANCE: 86.64215598742508
# (Venice -> Ravenna) DISTANCE: 112.64069747773023
# (Ravenna -> Prato) DISTANCE: 107.21657380016791
# (Prato -> Bergamo) DISTANCE: 230.38734462635284
# (Bergamo -> Terni) DISTANCE: 421.62308372903595
# (Terni -> Syracuse) DISTANCE: 651.0649487694699
# (Syracuse -> Bolzano) DISTANCE: 1097.016703773977
# (Bolzano -> Naples) DISTANCE: 670.3310207324232
# (Naples -> Andria) DISTANCE: 175.00968691893462
# (Andria -> Bari) DISTANCE: 50.17877214765558
# (Bari -> Piacenza) DISTANCE: 730.487440727087
# (Piacenza -> Messina) DISTANCE: 905.7825250125796
# (Messina -> Padua) DISTANCE: 858.0115542328692
# (Padua -> Foggia) DISTANCE: 529.3663216953859
# (Foggia -> Ancona) DISTANCE: 290.4028573916701
# (Ancona -> Latina) DISTANCE: 241.85490798374872
# (Latina -> Trieste) DISTANCE: 469.8156674075742
# (Trieste -> Turin) DISTANCE: 481.1852054412791
# (Turin -> Parma) DISTANCE: 210.49427792876835
# (Parma -> Monza) DISTANCE: 118.86975036286778
# (Monza -> Leghorn) DISTANCE: 239.95593564368414
# (Leghorn -> Milan) DISTANCE: 231.4966304535702
# (Milan -> Reggio nell'Emilia) DISTANCE: 142.62851446035404
# (Reggio nell'Emilia -> Trento) DISTANCE: 157.02006680398367
# (Trento -> Rome) DISTANCE: 478.5201316506459
# (Rome -> Rimini) DISTANCE: 241.1377928379251
# (Rimini -> Verona) DISTANCE: 197.91149042291212
# (Verona -> Cagliari) DISTANCE: 708.2000989648302
# (Cagliari -> Novara) DISTANCE: 693.1536668440472
# (Novara -> Perugia) DISTANCE: 397.63731540360305
# (Perugia -> Pescara) DISTANCE: 165.498242539523
# (Pescara -> Vicenza) DISTANCE: 404.5823285512894
# (Vicenza -> Taranto) DISTANCE: 729.7721086846036
# (Taranto -> Genoa) DISTANCE: 811.0865255632106
# TOTAL DISTANCE: 19297.54274123463
# PATH:
# (Leghorn -> Bologna) DISTANCE: 134.51292498261378
# (Bologna -> Turin) DISTANCE: 296.6880435083246
# (Turin -> Cagliari) DISTANCE: 661.372964783588
# (Cagliari -> Naples) DISTANCE: 476.8352631100359
# (Naples -> Giugliano in Campania) DISTANCE: 11.1526869070739
# (Giugliano in Campania -> Foggia) DISTANCE: 128.8781820519082
# (Foggia -> Vicenza) DISTANCE: 557.1719898512379
# (Vicenza -> Ancona) DISTANCE: 266.79616501220914
# (Ancona -> Modena) DISTANCE: 237.16017652663953
# (Modena -> Brescia) DISTANCE: 114.19040005018668
# (Brescia -> Terni) DISTANCE: 384.07502460810247
# (Terni -> Perugia) DISTANCE: 63.64271193762265
# (Perugia -> Novara) DISTANCE: 397.63731540360305
# (Novara -> Monza) DISTANCE: 52.80422977041385
# (Monza -> Rome) DISTANCE: 485.4934946472955
# (Rome -> Reggio nell'Emilia) DISTANCE: 348.0832758420256
# (Reggio nell'Emilia -> Milan) DISTANCE: 142.62851446035404
# (Milan -> Forlì) DISTANCE: 265.34550867718366
# (Forlì -> Florence) DISTANCE: 80.03075988738944
# (Florence -> Latina) DISTANCE: 290.102957969558
# (Latina -> Salerno) DISTANCE: 180.71323290471733
# (Salerno -> Sassari) DISTANCE: 524.7220607230245
# (Sassari -> Trieste) DISTANCE: 691.1383397456246
# (Trieste -> Padua) DISTANCE: 150.79546003219656
# (Padua -> Ferrara) DISTANCE: 66.56722292632472
# (Ferrara -> Andria) DISTANCE: 553.2532899024812
# (Andria -> Bari) DISTANCE: 50.17877214765558
# (Bari -> Catania) DISTANCE: 430.50090746323104
# (Catania -> Ravenna) DISTANCE: 805.4288210353067
# (Ravenna -> Genoa) DISTANCE: 261.19593100584683
# (Genoa -> Parma) DISTANCE: 118.5332719624068
# (Parma -> Taranto) DISTANCE: 743.4353300897322
# (Taranto -> Pescara) DISTANCE: 335.2535483003723
# (Pescara -> Venice) DISTANCE: 362.84806569915196
# (Venice -> Prato) DISTANCE: 197.37267532812427
# (Prato -> Piacenza) DISTANCE: 171.71642897444596
# (Piacenza -> Rimini) DISTANCE: 255.0605540892278
# (Rimini -> Verona) DISTANCE: 197.91149042291212
# (Verona -> Bergamo) DISTANCE: 107.01458931375457
# (Bergamo -> Palermo) DISTANCE: 895.5893866502112
# (Palermo -> Syracuse) DISTANCE: 206.4685647180968
# (Syracuse -> Reggio di Calabria) DISTANCE: 119.72689054756697
# (Reggio di Calabria -> Messina) DISTANCE: 12.477352214328397
# (Messina -> Trento) DISTANCE: 949.4399330535846
# (Trento -> Bolzano) DISTANCE: 49.93679674999438
# (Bolzano -> Leghorn) DISTANCE: 338.11404968821466
# TOTAL DISTANCE: 14169.9955556759

# %% [markdown]
# ## Approach 4: **Best greedy with insert mutation**
# This fourth approach, like the second one, tries to improve the best greedy solution by iteratively applying a mutation, which, in this case, is the insert mutation.<br>
# The fitness function is again based on the total distance of the path.

# %%
# mutation function
def insert_mutation(solution):
    edge_1 = random.randint(0, (NUM_CITIES - 2))
    edge_2 = random.randint(edge_1 + 1, (NUM_CITIES - 1))

    new_path = list()
    new_path.extend(solution[0: edge_1 + 1])
    new_path.append(solution[edge_2])
    new_path.extend(solution[edge_1 + 1: edge_2])
    new_path.extend(solution[edge_2 + 1: NUM_CITIES])
    new_solution = new_path

    return new_solution


# we start from the best greedy solution
solution = best_greedy[0].copy()
# iterative process
for _ in range(1000):
    new_solution = insert_mutation(solution)

    if fitness(new_solution) > fitness(solution):
        solution = new_solution

print_solution(solution)
# Out:
# PATH:
# (Ancona -> Rimini) DISTANCE: 90.5967461797061
# (Rimini -> Forlì) DISTANCE: 46.723760122246745
# (Forlì -> Ravenna) DISTANCE: 26.45904737732812
# (Ravenna -> Ferrara) DISTANCE: 66.67171194357726
# (Ferrara -> Bologna) DISTANCE: 43.42728615199659
# (Bologna -> Modena) DISTANCE: 37.29202792818561
# (Modena -> Reggio nell'Emilia) DISTANCE: 23.939721051289947
# (Reggio nell'Emilia -> Parma) DISTANCE: 26.942823860477837
# (Parma -> Piacenza) DISTANCE: 57.65426248112829
# (Piacenza -> Milan) DISTANCE: 60.64923118840254
# (Milan -> Monza) DISTANCE: 14.50856854090449
# (Monza -> Bergamo) DISTANCE: 33.91792128864521
# (Bergamo -> Brescia) DISTANCE: 46.01771032749969
# (Brescia -> Verona) DISTANCE: 61.41588754627765
# (Verona -> Vicenza) DISTANCE: 44.69517255475827
# (Vicenza -> Padua) DISTANCE: 30.129893989361843
# (Padua -> Venice) DISTANCE: 36.07208970412391
# (Venice -> Trieste) DISTANCE: 115.09339706818346
# (Trieste -> Bolzano) DISTANCE: 209.6848929934776
# (Bolzano -> Trento) DISTANCE: 49.93679674999438
# (Trento -> Novara) DISTANCE: 206.68711345185295
# (Novara -> Turin) DISTANCE: 84.45894281264431
# (Turin -> Genoa) DISTANCE: 123.19477068521964
# (Genoa -> Leghorn) DISTANCE: 146.36826834006118
# (Leghorn -> Prato) DISTANCE: 74.0242139473328
# (Prato -> Florence) DISTANCE: 17.17330189828679
# (Florence -> Perugia) DISTANCE: 119.19198932605904
# (Perugia -> Terni) DISTANCE: 63.64271193762265
# (Terni -> Rome) DISTANCE: 76.5411082252729
# (Rome -> Latina) DISTANCE: 56.837851102893964
# (Latina -> Giugliano in Campania) DISTANCE: 124.44567231892404
# (Giugliano in Campania -> Naples) DISTANCE: 11.1526869070739
# (Naples -> Salerno) DISTANCE: 46.24532696291669
# (Salerno -> Foggia) DISTANCE: 109.51661720605695
# (Foggia -> Andria) DISTANCE: 67.42173103569236
# (Andria -> Bari) DISTANCE: 50.17877214765558
# (Bari -> Taranto) DISTANCE: 77.62816934136235
# (Taranto -> Messina) DISTANCE: 293.01721721226914
# (Messina -> Reggio di Calabria) DISTANCE: 12.477352214328397
# (Reggio di Calabria -> Syracuse) DISTANCE: 119.72689054756697
# (Syracuse -> Catania) DISTANCE: 51.227395340192665
# (Catania -> Palermo) DISTANCE: 166.3570679647983
# (Palermo -> Cagliari) DISTANCE: 390.2811320384364
# (Cagliari -> Sassari) DISTANCE: 173.89062184125248
# (Sassari -> Pescara) DISTANCE: 508.60942288264704
# (Pescara -> Ancona) DISTANCE: 139.23847120123253
# TOTAL DISTANCE: 4431.363767937219

# %% [markdown]
# ## Approach 5: **Hill climbing with insert mutation and simulated annealing**
# This fifth approach, like the third one, starts from a random solution and improves it using simulated annealing strategy with insert mutation as a tweak function.<br>
# The fitness function is again based on the total distance of the path.

# %%
temperature = 1
BUFFER_SIZE = 4
buffer = list()


# mutation function
def insert_mutation_sa(solution):
    for _ in range(temperature):
        edge_1 = random.randint(0, (NUM_CITIES - 2))
        edge_2 = random.randint(edge_1 + 1, (NUM_CITIES - 1))

        new_path = list()
        new_path.extend(solution[0: edge_1 + 1])
        new_path.append(solution[edge_2])
        new_path.extend(solution[edge_1 + 1: edge_2])
        new_path.extend(solution[edge_2 + 1: NUM_CITIES])

    return new_path


# we start from a random solution
random_path = best_greedy[0].copy()
random.shuffle(random_path)
solution = random_path
print_solution(solution)

# iterative process
for _ in range(1000):
    new_solution = insert_mutation_sa(solution)

    buffer.append(fitness(new_solution) > fitness(solution))
    buffer = buffer[-BUFFER_SIZE:]

    if sum(buffer) > BUFFER_SIZE / 4 and temperature > 1:
        temperature -= 1
    elif sum(buffer) < BUFFER_SIZE / 4:
        temperature += 1

    if fitness(new_solution) > fitness(solution):
        solution = new_solution
    
print_solution(solution)
# Out:
# PATH:
# (Reggio nell'Emilia -> Forlì) DISTANCE: 123.99952263061773
# (Forlì -> Ancona) DISTANCE: 136.70372473443274
# (Ancona -> Florence) DISTANCE: 183.29551097355267
# (Florence -> Syracuse) DISTANCE: 820.2715034928696
# (Syracuse -> Sassari) DISTANCE: 710.9365674683115
# (Sassari -> Bolzano) DISTANCE: 679.3634325642092
# (Bolzano -> Taranto) DISTANCE: 820.6521448865335
# (Taranto -> Andria) DISTANCE: 115.55574212919072
# (Andria -> Giugliano in Campania) DISTANCE: 179.58271106771886
# (Giugliano in Campania -> Salerno) DISTANCE: 56.26767299492243
# (Salerno -> Rome) DISTANCE: 232.837926473714
# (Rome -> Cagliari) DISTANCE: 413.2531396256776
# (Cagliari -> Turin) DISTANCE: 661.372964783588
# (Turin -> Trieste) DISTANCE: 481.1852054412791
# (Trieste -> Padua) DISTANCE: 150.79546003219656
# (Padua -> Genoa) DISTANCE: 256.88038107912917
# (Genoa -> Ravenna) DISTANCE: 261.19593100584683
# (Ravenna -> Naples) DISTANCE: 431.0306603560136
# (Naples -> Ferrara) DISTANCE: 493.6375664899913
# (Ferrara -> Piacenza) DISTANCE: 154.25258534152854
# (Piacenza -> Milan) DISTANCE: 60.64923118840254
# (Milan -> Rimini) DISTANCE: 311.41697170771994
# (Rimini -> Modena) DISTANCE: 146.9762149215085
# (Modena -> Monza) DISTANCE: 165.94484669892304
# (Monza -> Venice) DISTANCE: 239.70819118381925
# (Venice -> Trento) DISTANCE: 118.66673356379675
# (Trento -> Messina) DISTANCE: 949.4399330535846
# (Messina -> Bologna) DISTANCE: 784.1067878343192
# (Bologna -> Bergamo) DISTANCE: 187.24219512717815
# (Bergamo -> Terni) DISTANCE: 421.62308372903595
# (Terni -> Latina) DISTANCE: 123.78731133093633
# (Latina -> Novara) DISTANCE: 561.0197274300605
# (Novara -> Leghorn) DISTANCE: 249.84229612826766
# (Leghorn -> Foggia) DISTANCE: 489.31124873337836
# (Foggia -> Reggio di Calabria) DISTANCE: 373.1612498775885
# (Reggio di Calabria -> Palermo) DISTANCE: 200.8198077021519
# (Palermo -> Bari) DISTANCE: 449.11351745170913
# (Bari -> Parma) DISTANCE: 673.1427552630914
# (Parma -> Perugia) DISTANCE: 251.53935592491914
# (Perugia -> Verona) DISTANCE: 281.98689415598864
# (Verona -> Brescia) DISTANCE: 61.41588754627765
# (Brescia -> Catania) DISTANCE: 981.2969721539517
# (Catania -> Vicenza) DISTANCE: 941.3608668113338
# (Vicenza -> Pescara) DISTANCE: 404.5823285512894
# (Pescara -> Prato) DISTANCE: 299.2910638376432
# (Prato -> Reggio nell'Emilia) DISTANCE: 98.23286619246431
# TOTAL DISTANCE: 17188.748691670666
# PATH:
# (Reggio nell'Emilia -> Brescia) DISTANCE: 98.76737589504454
# (Brescia -> Vicenza) DISTANCE: 103.07612833751455
# (Vicenza -> Verona) DISTANCE: 44.69517255475827
# (Verona -> Forlì) DISTANCE: 158.56803480936728
# (Forlì -> Ravenna) DISTANCE: 26.45904737732812
# (Ravenna -> Florence) DISTANCE: 105.30559521161433
# (Florence -> Ancona) DISTANCE: 183.29551097355267
# (Ancona -> Rome) DISTANCE: 206.84991190021685
# (Rome -> Latina) DISTANCE: 56.837851102893964
# (Latina -> Naples) DISTANCE: 134.743654502029
# (Naples -> Salerno) DISTANCE: 46.24532696291669
# (Salerno -> Reggio di Calabria) DISTANCE: 295.2224954278373
# (Reggio di Calabria -> Catania) DISTANCE: 84.28339538220968
# (Catania -> Syracuse) DISTANCE: 51.227395340192665
# (Syracuse -> Messina) DISTANCE: 126.40895916337286
# (Messina -> Palermo) DISTANCE: 192.10023199305985
# (Palermo -> Cagliari) DISTANCE: 390.2811320384364
# (Cagliari -> Sassari) DISTANCE: 173.89062184125248
# (Sassari -> Pescara) DISTANCE: 508.60942288264704
# (Pescara -> Bologna) DISTANCE: 324.43250038713836
# (Bologna -> Ferrara) DISTANCE: 43.42728615199659
# (Ferrara -> Venice) DISTANCE: 86.64215598742508
# (Venice -> Padua) DISTANCE: 36.07208970412391
# (Padua -> Trento) DISTANCE: 94.61307510139319
# (Trento -> Bolzano) DISTANCE: 49.93679674999438
# (Bolzano -> Trieste) DISTANCE: 209.6848929934776
# (Trieste -> Rimini) DISTANCE: 200.5394101874627
# (Rimini -> Perugia) DISTANCE: 106.54527123549394
# (Perugia -> Terni) DISTANCE: 63.64271193762265
# (Terni -> Giugliano in Campania) DISTANCE: 222.66977112300634
# (Giugliano in Campania -> Andria) DISTANCE: 179.58271106771886
# (Andria -> Taranto) DISTANCE: 115.55574212919072
# (Taranto -> Bari) DISTANCE: 77.62816934136235
# (Bari -> Foggia) DISTANCE: 117.19426014123634
# (Foggia -> Prato) DISTANCE: 453.6490654801784
# (Prato -> Leghorn) DISTANCE: 74.0242139473328
# (Leghorn -> Modena) DISTANCE: 131.9217598208624
# (Modena -> Piacenza) DISTANCE: 108.08714921947443
# (Piacenza -> Parma) DISTANCE: 57.65426248112829
# (Parma -> Genoa) DISTANCE: 118.5332719624068
# (Genoa -> Novara) DISTANCE: 117.05053035543504
# (Novara -> Turin) DISTANCE: 84.45894281264431
# (Turin -> Milan) DISTANCE: 124.69152967395101
# (Milan -> Bergamo) DISTANCE: 46.64788817127682
# (Bergamo -> Monza) DISTANCE: 33.91792128864521
# (Monza -> Reggio nell'Emilia) DISTANCE: 144.17999730359347
# TOTAL DISTANCE: 6409.850640451817

# %% [markdown]
# The following one is a fitness function based on the minimization of the intersections between the segments connecting the different cities in order to "simplify" the path as much as possible. This one was not implemented as it showed to be highly inefficient.

# %%
def orientation(p, q, r):
    val = (q[1] - p[1]) * (r[0] - q[0]) - (q[0] - p[0]) * (r[1] - q[1])
    if val == 0:
        return 0  
    elif val > 0:
        return 1  
    else:
        return 2 

def on_segment(p, q, r):
    return (min(p[0], r[0]) <= q[0] <= max(p[0], r[0]) and
            min(p[1], r[1]) <= q[1] <= max(p[1], r[1]))

def do_intersect(A, B, C, D):
    o1 = orientation(A, B, C)
    o2 = orientation(A, B, D)
    o3 = orientation(C, D, A)
    o4 = orientation(C, D, B)

    if o1 != o2 and o3 != o4:
        return True

    if o1 == 0 and on_segment(A, C, B):
        return True
    if o2 == 0 and on_segment(A, D, B):
        return True
    if o3 == 0 and on_segment(C, A, D):
        return True
    if o4 == 0 and on_segment(C, B, D):
        return True

    return False

def fitness_intersection(solution):
    num = 0
    for i in range(0, NUM_CITIES - 1):
        for j in range(0, NUM_CITIES - 1):
            if i != j:
                A = (solution[0][i].x, solution[0][i].y)
                B = (solution[0][i + 1].x, solution[0][i + 1].y)
                C = (solution[0][j].x, solution[0][j].y)
                D = (solution[0][j + 1].x, solution[0][j + 1].y)
                if do_intersect(A, B, C, D):
                    num += 1
    return -num
